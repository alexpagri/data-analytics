# %%
import psycopg2
from postgis.psycopg import register
from db_importer.settings import *
import pandas as pd
import math
import matplotlib.pyplot as plt
import numpy as np

class DatabaseConnection(object):
    def __enter__(self):
        self.conn = psycopg2.connect(f"dbname='{DB_NAME}' user='{DB_USER}' password='{DB_PASSWORD}' host='{DB_HOST}' port='{DB_PORT}'")
        self.conn.autocommit = True

        register(self.conn)
        self.cur = self.conn.cursor()
 
        return self.cur

    def __exit__(self, exc_type, exc_val, exc_tb):
        if exc_tb is None:
            self.conn.commit()
            self.cur.close()
            self.conn.close()
        else:
            self.conn.rollback()
            self.cur.close()
            self.conn.close()

# %%
from shapely.geometry import Point
from shapely.geometry import box

start_rect = box(13.4538,52.5143,13.4545,52.5154)
end_rect = box(13.4518,52.516,13.453,52.5163)

def crop_intersection_SimRa(x):
    mask_first = x.coords.apply(lambda x: start_rect.contains(Point(x)))
    mask_end = x.coords.apply(lambda x: end_rect.contains(Point(x)))
    try:
        first = mask_first[mask_first==True].index[0]
        last = mask_end[mask_end==True].index[-1]
        return x.loc[first:last]
    except:
        print('check')
        
def crop_intersection_SUMO(x):
    mask_first = x.apply(lambda coord: start_rect.contains(Point(coord['vehicle_x'], coord['vehicle_y'])), axis = 1)
    mask_end = x.apply(lambda coord: end_rect.contains(Point(coord['vehicle_x'], coord['vehicle_y'])), axis = 1)
    try:
        first = mask_first[mask_first==True].index[0]
        last = mask_end[mask_end==True].index[-1]
        return x[['vehicle_x', 'vehicle_y']].loc[first:last].to_numpy()
    except:
        asasd = 12
        #print('check')
        
        

def plot_location(x, color, alpha, scatter):
    lon = []
    lat = []
    for c in x.coords.values:
        lon.append(c[0])
        lat.append(c[1])
    plt.plot(lon, lat, c=color, alpha=alpha)
    if scatter:
        zero_v_coords = x.apply(lambda x: x.coords if x.velos == 0 else None,axis = 1)
        lon = []
        lat = []
        for c in zero_v_coords.values:
            if c == None:
                continue
            lon.append(c[0])
            lat.append(c[1])
        plt.scatter(lon, lat)
        
                
def to_float_arr(x):
    res = []
    for c in x:
        res.append(float(c))
    return res

# %%
with DatabaseConnection() as cur:
    cur.execute("""
SELECT filename,
       json_array_elements_text(st_asgeojson(geom_raw) :: json -> 'coordinates') AS coordinates,
       unnest(timestamps)                             timestamps,
       unnest(velos)                                  velos
FROM ride
where 
            st_intersects(geom, st_setsrid(
            st_makebox2d(st_makepoint(13.4538,52.5143), st_makepoint(13.4545,52.5154)), 4326))
        AND 
            st_intersects(geom,st_setsrid( st_makebox2d( st_makepoint(13.4518,52.516), st_makepoint(13.453,52.5163)), 4326))""")
    res = cur.fetchall()
    df = pd.DataFrame(res, columns=['filename', 'coords', 'timestamps', 'velos'])
    df = df[~df.coords.isnull()]
    df.coords = df.coords.apply(lambda x: x.replace('[', '').replace(']', '').split(','))
    df.coords = df.coords.apply(lambda x: to_float_arr(x))
    
    grouped = df.groupby('filename', as_index=False)
    crops = grouped.apply(lambda x: crop_intersection_SimRa(x))
crops
# Out:
#                  filename                        coords  \
# 0  14602  VM2_-1041096873  [13.453848861, 52.514945959]
#    14603  VM2_-1041096873  [13.453920366, 52.515106299]
#    14604  VM2_-1041096873  [13.453975927, 52.515279825]
#    14605  VM2_-1041096873  [13.454065523, 52.515461257]
#    14606  VM2_-1041096873  [13.454136003, 52.515647929]
# ...                   ...                           ...
# 45 20288    VM2_957666860  [13.453090189, 52.516070287]
#    20289    VM2_957666860   [13.45286974, 52.516143757]
#    20290    VM2_957666860  [13.452618019, 52.516200764]
#    20291    VM2_957666860  [13.452353869, 52.516244119]
#    20292    VM2_957666860  [13.452194301, 52.516290128]
#
#                       timestamps     velos
# 0  14602 2020-01-13 03:39:14.549  6.096690
#    14603 2020-01-13 03:39:17.593  6.254204
#    14604 2020-01-13 03:39:20.611  6.414643
#    14605 2020-01-13 03:39:23.629  6.557510
#    14606 2020-01-13 03:39:26.649  6.654408
# ...                          ...       ...
# 45 20288 2019-10-07 02:45:26.506  5.562594
#    20289 2019-10-07 02:45:29.539  5.728876
#    20290 2019-10-07 02:45:32.573  5.873560
#    20291 2019-10-07 02:45:35.639  6.018875
#    20292 2019-10-07 02:45:38.716  6.249370
#
# [1288 rows x 4 columns]

# %%
df_default = pd.read_csv('im_warschauer_sim_data/default.csv', delimiter=';')    
#df_im = pd.read_csv('im_warschauer_sim_data/im_res_lane.csv', delimiter=';')    
df_im_lane = pd.read_csv('im_warschauer_sim_data/im_res.csv', delimiter=';')    

dfs=[df_default, df_im_lane]

df_data = []
for df in dfs:
    res = df.groupby('vehicle_id').apply(lambda x: crop_intersection_SUMO(x)).dropna()
    df_data.append(res.to_numpy())

# %%
map_data = plt.figure(figsize=(10,10))
colors = [u'#1f77b4', u'#ff7f0e', u'#2ca02c']

crops.groupby('filename').apply(lambda x: plot_location(x, colors[2], 0.3, False))
for ride in df_data[0]:
    plt.plot(ride[:,0], ride[:,1],c =colors[0], alpha=.7)
for ride in df_data[1]:
    plt.plot(ride[:,0], ride[:,1],c =colors[1], alpha=.7)

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c=colors[0], label='SUMO parameterized')
plt.plot([], c=colors[1], label='intersection model')
plt.plot([], c=colors[2], label='SimRa')

plt.legend()
plt.savefig('images/im_bismarck_lane_loc.png', bbox_inches='tight')

plt.show()

# %%
import mplleaflet
mplleaflet.display(fig=map_data)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-68-9f9048d9220e> in <module>
#       1 import mplleaflet
# ----> 2 mplleaflet.display(fig=map_data)
#
# ~/GIT/SimRa2/env/lib/python3.8/site-packages/mplleaflet/_display.py in display(fig, closefig, **kwargs)
#     151         plt.close(fig)
#     152
# --> 153     html = fig_to_html(fig, **kwargs)
#     154
#     155     # We embed everything in an iframe.
#
# ~/GIT/SimRa2/env/lib/python3.8/site-packages/mplleaflet/_display.py in fig_to_html(fig, template, tiles, crs, epsg, embed_links)
#      82     renderer = LeafletRenderer(crs=crs, epsg=epsg)
#      83     exporter = Exporter(renderer)
# ---> 84     exporter.run(fig)
#      85
#      86     attribution = _attribution + ' | ' + tiles[1]
#
# ~/GIT/SimRa2/env/lib/python3.8/site-packages/mplleaflet/mplexporter/exporter.py in run(self, fig)
#      49             import matplotlib.pyplot as plt
#      50             plt.close(fig)
# ---> 51         self.crawl_fig(fig)
#      52
#      53     @staticmethod
#
# ~/GIT/SimRa2/env/lib/python3.8/site-packages/mplleaflet/mplexporter/exporter.py in crawl_fig(self, fig)
#     116                                        props=utils.get_figure_properties(fig)):
#     117             for ax in fig.axes:
# --> 118                 self.crawl_ax(ax)
#     119
#     120     def crawl_ax(self, ax):
#
# ~/GIT/SimRa2/env/lib/python3.8/site-packages/mplleaflet/mplexporter/exporter.py in crawl_ax(self, ax)
#     123                                      props=utils.get_axes_properties(ax)):
#     124             for line in ax.lines:
# --> 125                 self.draw_line(ax, line)
#     126             for text in ax.texts:
#     127                 self.draw_text(ax, text)
#
# ~/GIT/SimRa2/env/lib/python3.8/site-packages/mplleaflet/mplexporter/exporter.py in draw_line(self, ax, line, force_trans)
#     192         label = line.get_label()
#     193         if markerstyle or linestyle:
# --> 194             self.renderer.draw_marked_line(data=data, coordinates=coordinates,
#     195                                            linestyle=linestyle,
#     196                                            markerstyle=markerstyle,
#
# ~/GIT/SimRa2/env/lib/python3.8/site-packages/mplleaflet/mplexporter/renderers/base.py in draw_marked_line(self, data, coordinates, linestyle, markerstyle, label, mplobj)
#     153         """
#     154         if linestyle is not None:
# --> 155             self.draw_line(data, coordinates, linestyle, label, mplobj)
#     156         if markerstyle is not None:
#     157             self.draw_markers(data, coordinates, markerstyle, label, mplobj)
#
# ~/GIT/SimRa2/env/lib/python3.8/site-packages/mplleaflet/mplexporter/renderers/base.py in draw_line(self, data, coordinates, style, label, mplobj)
#     182         pathstyle['edgecolor'] = pathstyle.pop('color')
#     183         pathstyle['edgewidth'] = pathstyle.pop('linewidth')
# --> 184         self.draw_path(data=data, coordinates=coordinates,
#     185                        pathcodes=pathcodes, style=pathstyle, mplobj=mplobj)
#     186
#
# ~/GIT/SimRa2/env/lib/python3.8/site-packages/mplleaflet/leaflet_renderer.py in draw_path(self, data, coordinates, pathcodes, style, offset, offset_coordinates, mplobj)
#     131             else:
#     132                 geometry_type = 'LineString'
# --> 133                 coords = rings[0]
#     134
#     135         feature = {
#
# IndexError: list index out of range
